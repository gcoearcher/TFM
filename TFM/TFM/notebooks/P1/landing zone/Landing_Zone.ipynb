# %%
from pyspark.sql import SparkSession, functions as F
from delta import configure_spark_with_delta_pip
import os

# %%
builder = SparkSession.builder \
    .appName("Delta Lake") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
path_data = "./../../../data/raw/ç"
types = ['csv', 'parquet', 'json', 'txt']
sources = ['Kaggle', 'uci', 'AWS']

# %%
import os
import glob

dfs = {}

for source in sources:
    for file_type in types:

        path = f'{path_data}{source}/{file_type}'

        if os.path.exists(path):
            pattern = os.path.join(path, "**/*." + file_type)
            files = glob.glob(pattern, recursive=True)

            for file in files:
                try:
                    df = spark.read.option("header", "true").format(file_type).load(file) #.limit(1000)

                    rel_path = file.replace("/", "_").replace(".", "_")
                    save_path = f"./../../../data/interim/{source}/{rel_path}"

                    df.write.format("delta").mode("overwrite").save(save_path)

                    print(f"Loaded {df.count()} rows for file {file}")
                except Exception as e:
                    print(f"Error al procesar {file}: {e}")
# Out:
# Loaded 31962 rows for file ./../../../data/raw/Kaggle/csv/twitter.csv
# Loaded 5937 rows for file ./../../../data/raw/Kaggle/csv/Emotion_classify_Data.csv
# 25/08/12 12:11:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 25/08/12 12:11:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 25/08/12 12:11:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 25/08/12 12:11:51 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , text, Emotion
#  Schema: _c0, text, Emotion
# Expected: _c0 but found:
# CSV file: file:///home/provira/Documents/TFM/TFM/data/raw/Kaggle/csv/emotion_sentimen_dataset.csv
# 25/08/12 12:11:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 25/08/12 12:11:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 25/08/12 12:11:53 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 25/08/12 12:11:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 25/08/12 12:11:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 25/08/12 12:11:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# Loaded 839555 rows for file ./../../../data/raw/Kaggle/csv/emotion_sentimen_dataset.csv
# Loaded 11327 rows for file ./../../../data/raw/Kaggle/csv/DailyDialog.csv
# 25/08/12 12:12:01 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Loaded 1000 rows for file ./../../../data/raw/Kaggle/csv/tweet_sentiment.csv
# Loaded 71219 rows for file ./../../../data/raw/Kaggle/csv/GoEmotions/goemotions_3.csv
# Loaded 69997 rows for file ./../../../data/raw/Kaggle/csv/GoEmotions/goemotions_2.csv
# Loaded 69995 rows for file ./../../../data/raw/Kaggle/csv/GoEmotions/goemotions_1.csv
# Loaded 416809 rows for file ./../../../data/raw/Kaggle/parquet/train-00000-of-00001.parquet
